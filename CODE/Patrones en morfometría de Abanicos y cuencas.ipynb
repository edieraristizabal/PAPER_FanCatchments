# %%
import pandas as pd
import numpy as np
import datetime
import glob
import matplotlib.pyplot as plt
import seaborn as sns
# import seaborn as sns

# %%
data=pd.read_excel("G:\My Drive\INVESTIGACION\PAPERS\ELABORACION\PAPER_FanCatchments/Data/Excel/Eng-MorfometriaCuencasAbanicos3032.xlsx", engine='openpyxl')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data=pd.read_excel("G:\My Drive\INVESTIGACION\PAPERS\ELABORACION\PAPER_FanCatchments/Data/Excel/Eng-MorfometriaCuencasAbanicos3032.xlsx", engine='openpyxl')
#
# File ~\miniconda3\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
# ...

# %%
data = pd.DataFrame(df)

# %% [markdown]
# #Correlacion de Pearson todas las variables

# %%
import seaborn as sns
plt.figure(figsize=(30,30))
cor = np.round(data.iloc[:,:-1].corr(method ='pearson'),4)
cor = data.corr(method ='pearson')
plt.title('Análisis de correlación')
mask=np.array(cor)
mask[np.tril_indices_from(mask)]=False
sns.heatmap(cor, annot=True, mask=mask, cmap=plt.cm.Reds, annot_kws={"size":12})
sns.set(font_scale=2)
plt.tight_layout()

#resultados = '/content/drive/My Drive/TESIS Emanuel - Ing. Geológica 2020/Resultados '
#plt.savefig(resultados+'/Corrpearsontot.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 import seaborn as sns
#       2 plt.figure(figsize=(30,30))
# ----> 3 cor = np.round(data.iloc[:,:-1].corr(method ='pearson'),4)
#       4 cor = data.corr(method ='pearson')
#       5 plt.title('Análisis de correlación')
#
# File ~\miniconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\miniconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# ...

# %%
morfoDirect=data.drop(['Factor_forma_abanico', 'Altura_max', 'Altura_min','Tipo de Abanico', 'Tipo de asentamiento', 'Poblado', 'Cordillera','Stream Length Ratio', 'Bifurcation Ratio', 'Ro Coefficient','Form Factor', 'Elongation Ratio', 'Circularity Ratio', 'Compactness Coefficient', 'Texture Ratio', 'Fitness Ratio', 'Wandering ratio', 'Stream Frequency', 'Drainage Density', 'Constant of Channel Maintenance', 'Drainage Intensity', 'Infiltration Number', 'Coeficiente de torrencialidad', 'Length of overland flow','Relief Ratio', 'Ruggedness Number', 'Melton Index', 'Unidad geologica', 'Litologia', 'Subzona hidrografica'],1)
morfo_array_cont=data.values
morfoDirect.head()

# %% [markdown]
# #Correlacion de Pearson variables no dependientes (area, pendiente, number of stream...)

# %%
import seaborn as sns
plt.figure(figsize=(30,30))
cor = np.round(morfoDirect.iloc[:,:-1].corr(method ='pearson'),4)
cor = morfoDirect.corr(method ='pearson')
plt.title('Análisis de correlación')
mask=np.array(cor)
mask[np.tril_indices_from(mask)]=False
sns.heatmap(cor, annot=True, mask=mask, cmap=plt.cm.Reds, annot_kws={"size":14})
sns.set(font_scale=2)
plt.tight_layout()

resultados = '/content/drive/My Drive/TESIS Emanuel - Ing. Geológica 2020/Resultados '
plt.savefig(resultados+'/CorrpearsonDir.png')

# %% [markdown]
# #Relacion de variables importantes en base al estado del arte

# %% [markdown]
# ## area abanico vs area cuenca  Hooke (1968), entre otros

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Area_cuenca', y='Area_abanico', data=data,hue="Tipo de Abanico", palette="tab10");

# %% [markdown]
# ## inclinacion del abanico vs area cuenca  Bull (1962), entre otros

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Area_cuenca', y='Inclinacion del abanico',hue="Tipo de Abanico", data=data, palette="tab10");

# %% [markdown]
# ## inclinacion del abanico vs melton index, (Church y Mark, 1980), entre otros

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Melton Index', y='Inclinacion del abanico', data=data,hue="Tipo de Abanico", palette="tab10");

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Melton Index', y='Pendiente_media__abanico', data=data,hue="Tipo de Abanico", palette="tab10");

# %% [markdown]
# ##Volumen del abanico vs area de la cuenca Whipple y Trayler (1996); Giles (2010)

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Volumen_abanico', y='Area_cuenca', data=data,hue="Tipo de Abanico", palette="tab10");

# %% [markdown]
# ##Volumen del abanico vs area del abanico Whipple y Trayler (1996); Giles (2010)

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Volumen_abanico', y='Area_abanico', data=data,hue="Tipo de Abanico", palette="tab10");

# %% [markdown]
# ##Pendiente del abanico vs pendiente de la cuenca, Hooke (1968)

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Pendiente_media__abanico', y='Pendiente media cuenca', data=data,hue="Tipo de Abanico", palette="tab10");

# %% [markdown]
# ## Diferencia del relieve del abanico y la cuenca

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Diferencia_Relieve__abanico', y='Diferencia_Relieve__cuenca', hue="Tipo de Abanico", data=data, palette="tab10");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-17eff876b45f> in <cell line: 1>()
# ----> 1 plt.figure(figsize=(10,10))
#       2 sns.scatterplot(x='Diferencia_Relieve__abanico', y='Diferencia_Relieve__cuenca', hue="Tipo de Abanico", data=data, palette="tab10");
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(10,10))
sns.lmplot(x='Diferencia_Relieve__abanico', y='Diferencia_Relieve__cuenca', hue="Tipo de Abanico", data=data, palette="tab10")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-17956e7c54d4> in <cell line: 1>()
# ----> 1 plt.figure(figsize=(10,10))
#       2 sns.lmplot(x='Diferencia_Relieve__abanico', y='Diferencia_Relieve__cuenca', hue="Tipo de Abanico", data=data, palette="tab10")
#
# NameError: name 'plt' is not defined

# %% [markdown]
# #Relaciones lineales con LA CORDILLERA

# %%
morfometria=data.drop(['Factor_forma_abanico', 'Altura_max', 'Perimetro_abanico', 'Longitud_abanico', 'Ancho_abanico','Altura_min','Form Factor','Tipo de Abanico', 'Tipo de asentamiento', 'Poblado','Curvatura_Perfil_media', 'Curvatura_Plana_media', 'Rugosidad_media','Main Stream Order', 'Number of Streams', 'Stream Length Ratio', 'Bifurcation Ratio', 'Ro Coefficient','Perimetro_cuenca', 'Elongation Ratio', 'Circularity Ratio', 'Compactness Coefficient', 'Texture Ratio', 'Fitness Ratio', 'Wandering ratio', 'Stream Frequency', 'Drainage Density', 'Constant of Channel Maintenance', 'Drainage Intensity', 'Infiltration Number', 'Coeficiente de torrencialidad', 'Length of overland flow', 'Relief Ratio', 'Ruggedness Number', 'Melton Index', 'Unidad geologica', 'Litologia', 'Subzona hidrografica'],1)
morfo_array_cont=data.values
morfometria.head()

# %%
sns.pairplot(morfometria, hue="Cordillera", height=2.5)

resultados = '/content/drive/My Drive/TESIS Emanuel - Ing. Geológica 2020/Resultados '
plt.savefig(resultados+'/globalCordillera.png')

# %% [markdown]
# ## Relaciones Destacables

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Area_abanico', y='Pendiente media cuenca', hue="Cordillera", data=data, palette="tab10");

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Area_abanico', y='Pendiente_media__abanico', hue="Cordillera", data=data, palette="tab10");

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Area_abanico', y='Diferencia_Relieve__cuenca', hue="Cordillera", data=data, palette="tab10");

# %%
plt.figure(figsize=(10,10))
sns.lmplot(x='Area_abanico', y='Diferencia_Relieve__cuenca', hue="Cordillera", data=data, palette="tab10")

# %% [markdown]
# #Relaciones lineales con El TIPO DE ABANICO

# %%
morfometria=data.drop(['Factor_forma_abanico', 'Altura_max', 'Perimetro_abanico', 'Longitud_abanico', 'Ancho_abanico','Altura_min','Form Factor','Cordillera', 'Tipo de asentamiento', 'Poblado','Curvatura_Perfil_media', 'Curvatura_Plana_media', 'Rugosidad_media','Main Stream Order', 'Number of Streams', 'Stream Length Ratio', 'Bifurcation Ratio', 'Ro Coefficient','Perimetro_cuenca', 'Elongation Ratio', 'Circularity Ratio', 'Compactness Coefficient', 'Texture Ratio', 'Fitness Ratio', 'Wandering ratio', 'Stream Frequency', 'Drainage Density', 'Constant of Channel Maintenance', 'Drainage Intensity', 'Infiltration Number', 'Coeficiente de torrencialidad', 'Length of overland flow', 'Relief Ratio', 'Ruggedness Number', 'Melton Index', 'Unidad geologica', 'Litologia', 'Subzona hidrografica'],1)
morfo_array_cont=data.values
morfometria.head()

# %%
sns.pairplot(morfometria, hue="Tipo de Abanico", height=2.5)
sns.set(font_scale=1)
resultados = '/content/drive/My Drive/TESIS Emanuel - Ing. Geológica 2020/Resultados '
plt.savefig(resultados+'/globalTipodeAbanico.png')

# %% [markdown]
# ##Relaciones destacables

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Volumen_abanico', y='Diferencia_Relieve__cuenca', hue="Tipo de Abanico", data=data, palette="tab10")

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Diferencia_Relieve__cuenca', y='Pendiente media cuenca', hue="Tipo de Abanico", data=data, palette="tab10")

# %%
plt.figure(figsize=(10,10))
sns.lmplot(x='Diferencia_Relieve__cuenca', y='Pendiente media cuenca', hue="Tipo de Abanico", data=data, palette="tab10")

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Volumen_abanico', y='Length of Basin', hue="Tipo de Abanico", data=data, palette="tab10")

# %% [markdown]
# #Relaciones lineales con la SUBZONA HIDROGRAFICA

# %%
morfometria=data.drop(['Factor_forma_abanico', 'Altura_max', 'Perimetro_abanico', 'Longitud_abanico', 'Ancho_abanico','Altura_min','Form Factor','Cordillera', 'Tipo de asentamiento', 'Poblado','Curvatura_Perfil_media', 'Curvatura_Plana_media', 'Rugosidad_media','Main Stream Order', 'Number of Streams', 'Stream Length Ratio', 'Bifurcation Ratio', 'Ro Coefficient','Perimetro_cuenca', 'Elongation Ratio', 'Circularity Ratio', 'Compactness Coefficient', 'Texture Ratio', 'Fitness Ratio', 'Wandering ratio', 'Stream Frequency', 'Drainage Density', 'Constant of Channel Maintenance', 'Drainage Intensity', 'Infiltration Number', 'Coeficiente de torrencialidad', 'Length of overland flow', 'Relief Ratio', 'Ruggedness Number', 'Melton Index', 'Unidad geologica', 'Litologia'],1)
morfo_array_cont=data.values
morfometria.head()

# %%
sns.pairplot(morfometria, hue='Subzona hidrografica', palette="tab10", height=2.5)
sns.set(font_scale=1)
resultados = '/content/drive/My Drive/TESIS Emanuel - Ing. Geológica 2020/Resultados '
plt.savefig(resultados+'/globalSubZonaHidro.png')

# %% [markdown]
# ##Relaciones destacables

# %% [markdown]
# #Relaciones lineales con LA GEOLOGIA

# %%
morfometria=data.drop(['Factor_forma_abanico', 'Altura_max', 'Perimetro_abanico', 'Longitud_abanico', 'Ancho_abanico','Altura_min','Form Factor','Cordillera', 'Tipo de asentamiento', 'Poblado','Curvatura_Perfil_media', 'Curvatura_Plana_media', 'Rugosidad_media','Main Stream Order', 'Number of Streams', 'Stream Length Ratio', 'Bifurcation Ratio', 'Ro Coefficient','Perimetro_cuenca', 'Elongation Ratio', 'Circularity Ratio', 'Compactness Coefficient', 'Texture Ratio', 'Fitness Ratio', 'Wandering ratio', 'Stream Frequency', 'Drainage Density', 'Constant of Channel Maintenance', 'Drainage Intensity', 'Infiltration Number', 'Coeficiente de torrencialidad', 'Length of overland flow', 'Relief Ratio', 'Ruggedness Number', 'Melton Index', 'Unidad geologica', 'Subzona hidrografica'],1)
morfo_array_cont=data.values
morfometria.head()

# %%
sns.pairplot(morfometria, hue="Litologia", height=2.5)
sns.set(font_scale=1)
resultados = '/content/drive/My Drive/TESIS Emanuel - Ing. Geológica 2020/Resultados '
plt.savefig(resultados+'/globalGeologia.png')

# %% [markdown]
# ##Relaciones destacables

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Pendiente media cuenca', y='Pendiente_media__abanico', hue="Litologia", data=data, palette="tab10")

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Pendiente media cuenca', y='Area_abanico', hue="Litologia", data=data, palette="tab10")

# %% [markdown]
# #Relaciones lineales con LA POBLACION en el abanico

# %%
morfometria=data.drop(['Factor_forma_abanico', 'Altura_max', 'Perimetro_abanico', 'Longitud_abanico', 'Ancho_abanico','Altura_min','Form Factor','Cordillera', 'Poblado','Curvatura_Perfil_media', 'Curvatura_Plana_media', 'Rugosidad_media','Main Stream Order', 'Number of Streams', 'Stream Length Ratio', 'Bifurcation Ratio', 'Ro Coefficient','Perimetro_cuenca', 'Elongation Ratio', 'Circularity Ratio', 'Compactness Coefficient', 'Texture Ratio', 'Fitness Ratio', 'Wandering ratio', 'Stream Frequency', 'Drainage Density', 'Constant of Channel Maintenance', 'Drainage Intensity', 'Infiltration Number', 'Coeficiente de torrencialidad', 'Length of overland flow', 'Relief Ratio', 'Ruggedness Number', 'Melton Index', "Litologia",'Unidad geologica', 'Subzona hidrografica'],1)
morfo_array_cont=data.values
morfometria.head()

# %%
sns.pairplot(morfometria, hue="Tipo de asentamiento", height=2.5)
sns.set(font_scale=1)
resultados = '/content/drive/My Drive/TESIS Emanuel - Ing. Geológica 2020/Resultados '
plt.savefig(resultados+'/globalAsentamiento.png')

# %% [markdown]
# ##Relaciones destacables

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Pendiente_media__abanico', y='Area_cuenca', hue="Tipo de asentamiento", data=data, palette="tab10")

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Length of Basin', y='Inclinacion del abanico', hue="Tipo de asentamiento", data=data, palette="tab10")

# %% [markdown]
# # Boxplots variables

# %%
sns.boxplot(x="Litologia", y='Area abanico (km^2)', data=data)

plt.show()

# %%
data.boxplot(column="Area abanico (km^2)", by = "Litologia");

# %%
fig, axes = plt.subplots(2, 4, figsize=(10,4))
sns.boxplot(x="Tipo de Abanico", y="Area_abanico", data=data, ax=axes[0, 0])
sns.boxplot(x="Tipo de Abanico", y="Area_cuenca", data=data, ax=axes[0, 1])
sns.boxplot(data['Diferencia_Relieve__abanico'], ax=axes[0, 2])
sns.boxplot(data['Diferencia_Relieve__cuenca'], ax=axes[1, 0])
sns.boxplot(data['Perimetro_cuenca'], ax=axes[1, 1])
sns.boxplot(data['Perimetro_abanico'], ax=axes[1, 2])
sns.boxplot(data['Longitud_abanico'], ax=axes[1, 3])
sns.boxplot(data['Ancho_abanico'], ax=axes[0, 3])
fig.tight_layout()
plt.setp(axes, yticks=[]),

# %%
fig, axes = plt.subplots(2, 4, figsize=(10,4))
data.boxplot(column="Area_abanico", by = "Tipo de Abanico",ax=axes[0, 0]);
data.boxplot(column="Area_cuenca", by = "Tipo de Abanico",ax=axes[0, 1]);
data.boxplot(column="Perimetro_abanico", by = "Tipo de Abanico",ax=axes[0, 2]);

# %% [markdown]
# #Kernel Density estimation KDE y boxplots

# %%
fig, axes = plt.subplots(2, 4, figsize=(10,4))
sns.kdeplot(data['Area abanico (km^2)'], ax=axes[0, 0])
sns.kdeplot(data['Area cuenca (km^2)'], data=data, ax=axes[0, 1])
sns.kdeplot(data['Diferencia Relieve abanico (km)'], ax=axes[0, 2])
sns.kdeplot(data['Relieve cuenca (km)'], ax=axes[0, 3])
sns.kdeplot(data['Perimetro abanico (km)'], ax=axes[1, 0])

# %%
df=pd.read_excel('/content/drive/My Drive/TESIS Emanuel - Ing. Geológica 2020/Eng-MorfometriaCuencasAbanicos303.xlsx')

# %%
data = pd.DataFrame(df)
print(list(data.columns))
data

# %%
sns.kdeplot(data['Fan area (km^2)'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Fan area (km^2)', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-4,6)

# %%
sns.distplot(data["Fan area (km^2)"], color="g")
plt.xlabel('Fan area (km^2)', size="20")
plt.ylabel('Density', size="20")

# %%
ax = sns.boxplot(x="Fan area (km^2)", data=data)

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=data["Fan area (km^2)"], color="g")

# %%
sns.kdeplot(data['Fan perimeter (km)'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Fan perimeter (km)', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-4,15)

# %%
sns.distplot(data["Fan perimeter (km)"], color="g")
plt.xlabel('Fan perimeter (km)', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data['Fan length (km)'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Fan length (km)', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-1,5)

# %%
sns.distplot(data["Fan length (km)"], color="g")
plt.xlabel('Fan length (km)', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data['Fan width (km)'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Fan width (km)', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-1,4)

# %%
sns.distplot(data["Fan width (km)"], color="g")
plt.xlabel('Fan width (km)', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data['Fan relief (km)'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Fan relief (km)', size="23")
plt.ylabel('Density', size="26")
plt.xlim(-0.2,0.6)

# %%
sns.distplot(data["Fan relief (km)"], color="g")
plt.xlabel('Fan relief (km)', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data['Fan slope(°)'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Fan slope(°)', size="24")
plt.ylabel('Density', size="26")
plt.xlim(-5,30)

# %%
sns.distplot(data["Fan slope(°)"], color="g")
plt.xlabel('Fan slope(°)', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data['Fan ruggednes '], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Fan ruggedness', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-0.2,3)

# %%
sns.distplot(data["Fan ruggednes "], color="g")
plt.xlabel('Fan ruggednes ', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data['Fan volume (km^3)'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Fan volume (km^3)', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-0.5,2)

# %%
sns.distplot(data["Fan volume (km^3)"], color="g")
plt.xlabel('Fan volume (km^3)', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data['Main stream order'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Main stream order', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-0.5,11)

# %%
sns.distplot(data["Main stream order"], color="b")
plt.xlabel('Main stream order', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data['Number of streams '], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Number of streams', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-3000,7500)

# %%
sns.distplot(data["Number of streams "], color="b")
plt.xlabel('Number of streams ', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data[' Stream length (km)'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Stream length (km)', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-1000,2000)

# %%
sns.distplot(data[" Stream length (km)"], color="b")
plt.xlabel(' Stream length (km)', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data['Main stream length (km)'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Main stream length (km)', size="22")
plt.ylabel('Density', size="26")
plt.xlim(-5,45)

# %%
sns.distplot(data["Main stream length (km)"], color="b")
plt.xlabel('Main stream length (km)', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data[' Stream length ratio'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Stream length ratio', size="21")
plt.ylabel('Density', size="26")
plt.xlim(-1,12)

# %%
sns.distplot(data[" Stream length ratio"], color="b")
plt.xlabel(' Stream length ratio', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data[' Ro Coefficient'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Ro Coefficient', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-0.5,5)

# %%
sns.distplot(data[" Ro Coefficient"], color="b")
plt.xlabel(' Ro Coefficient', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data['Length of catchmen (km)'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Length of catchment (km)', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-10,35)

# %%
sns.distplot(data["Length of catchmen (km)"], color="b")
plt.xlabel('Length of catchmen (km)', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data['Catchment area (km^2)'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Catchment area (km^2)', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-200,320)

# %%
sns.distplot(data["Catchment area (km^2)"], color="b")
plt.xlabel('Catchment area (km^2)', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data['Catchment perimeter (km)'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Catchment perimeter (km)', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-70,150)

# %%
sns.distplot(data["Catchment perimeter (km)"], color="b")
plt.xlabel('Catchment perimeter (km)', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data['Form factor'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Form factor', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-0.1,1.3)

# %%
sns.distplot(data["Form factor"], color="b")
plt.xlabel('Form factor', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data['Texture ratio'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Texture ratio', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-2,45)

# %%
sns.distplot(data["Texture ratio"], color="b")
plt.xlabel('Texture ratio', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data['Fitness ratio'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Fitness ratio', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-0,0.60)

# %%
sns.kdeplot(data['Wandering ratio'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Wandering ratio', size="26")
plt.ylabel('Density', size="26")
plt.xlim(0,2)

# %%
sns.kdeplot(data['Drainage density'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Drainage density', size="26")
plt.ylabel('Density', size="26")
plt.xlim(0,7)

# %%
sns.distplot(data["Drainage density"], color="b")
plt.xlabel('Drainage density', size="20")
plt.ylabel('Density', size="20")

# %%
sns.kdeplot(data['Drainage intensity'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Drainage intensity', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-2,18)

# %%
sns.kdeplot(data['Torrentiality coefficient'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Torrentiality coefficient', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-2,23)

# %%
sns.kdeplot(data['Catchment relief (km)'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Catchment relief (km)', size="26")
plt.ylabel('Density', size="26")

# %%
sns.kdeplot(data['Mean basin slope (°)'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Mean basin slope (°)', size="26")
plt.ylabel('Density', size="26")

# %%
sns.kdeplot(data[' Slope  of  the  catchment  channel (°)'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Slope  of  the  catchment  channel (°)', size="23")
plt.ylabel('Density', size="26")

# %%
sns.kdeplot(data['Relief ratio'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Relief ratio', size="26")
plt.ylabel('Density', size="26")

# %%
sns.kdeplot(data['Ruggedness number'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Ruggedness number', size="26")
plt.ylabel('Density', size="26")
plt.xlim(-9,40)

# %%
sns.kdeplot(data['Melton index'], linewidth="5")

parameters = {'xtick.labelsize': 20,
          'ytick.labelsize': 20,
}
plt.rcParams.update(parameters)

plt.xlabel('Melton index', size="26")
plt.ylabel('Density', size="26")

# %%
#hacer los otros 40 plots

# %% [markdown]
# #Scattering Matriz

# %%
df=pd.read_excel('/content/drive/My Drive/TESIS Emanuel - Ing. Geológica 2020/Scatter-MorfometriaCuencasAbanicos303.xlsx')

# %%
data = pd.DataFrame(df)
print(list(data.columns))
data

# %%
#Matriz de scattering utilizando seaborn
sns.pairplot(data, hue='Catchment');
parameters = {
          'xtick.labelsize': 19,
          'ytick.labelsize': 19,
          'legend.title_fontsize' : 25,
          'legend.fontsize' : 25}
plt.rcParams.update(parameters)

# %%
df=pd.read_excel('/content/drive/My Drive/TESIS Emanuel - Ing. Geológica 2020/Eng-MorfometriaCuencasAbanicos3032_newSCATTER.xlsx')

# %%
data = pd.DataFrame(df)
print(list(data.columns))
data

# %%
#Matriz de scattering utilizando seaborn
sns.pairplot(data, hue='Torrential flow reports');
parameters = {
          'xtick.labelsize': 19,
          'ytick.labelsize': 19,
          'legend.title_fontsize' : 25,
          'legend.fontsize' : 25}
plt.rcParams.update(parameters)

# %%
df=pd.read_excel('/content/drive/My Drive/TESIS Emanuel - Ing. Geológica 2020/Scatter-MorfometriaCuencasAbanicos303-2.xlsx')

# %%
data = pd.DataFrame(df)
print(list(data.columns))
data

# %%
#Matriz de scattering utilizando seaborn
sns.pairplot(data, hue='Torrential flow reports');
parameters = {
          'xtick.labelsize': 19,
          'ytick.labelsize': 19,
          'legend.title_fontsize' : 25,
          'legend.fontsize' : 25}
plt.rcParams.update(parameters)
