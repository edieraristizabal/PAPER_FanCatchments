# %% [markdown]
# # Create files

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as sts
import seaborn as sns
import geopandas as gpd
from geopandas import GeoDataFrame

import warnings
warnings.simplefilter("ignore")
pd.set_option('display.max_columns', None)

# %%
data=pd.read_excel("G:\My Drive\INVESTIGACION\SEGUIMIENTO ESTUDIANTES\PDG\TESIS Emanuel - Ing. Geológica 2020/Eng-MorfometriaCuencasAbanicos3032.xlsx", engine='openpyxl')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 56 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   ID                                             304 non-null    int64
#  1   Fan area (km^2)                                304 non-null    float64
#  2   Fan perimeter (km)                             304 non-null    float64
#  3   Fan length (km)                                304 non-null    float64
#  4   Fan width (km)                                 304 non-null    float64
#  5   Form factor of fan                             304 non-null    float64
#  6   Altura max (km)                                304 non-null    float64
#  7   Altura min (km)                                304 non-null    float64
#  8   Fan relief (km)                                304 non-null    float64
# ...

# %%
data.index[data["Bifurcation ratio"]=="1.,5"]
# Out:
# Index([79], dtype='int64')

# %%
data.loc[79, "Bifurcation ratio"] = 1.5

# %%
data["Bifurcation ratio"]=data["Bifurcation ratio"].astype(float)

# %%
data=data.drop(columns=["Unnamed: 27","theta"])

# %%
data1=pd.read_excel("G:\My Drive\INVESTIGACION\SEGUIMIENTO ESTUDIANTES\PDG\TESIS Emanuel - Ing. Geológica 2020/Morfometria_Cuencas_Abanicos_NorthernAndes.xlsx", engine='openpyxl')
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 54 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ID                                       304 non-null    int64
#  1   Fan area (km^2)                          304 non-null    float64
#  2   Fan perimeter (km)                       304 non-null    float64
#  3   Fan length (km)                          304 non-null    float64
#  4   Fan width (km)                           304 non-null    float64
#  5   Form factor of fan                       304 non-null    float64
#  6   Altura max (km)                          304 non-null    float64
#  7   Altura min (km)                          304 non-null    float64
#  8   Fan relief (km)                          304 non-null    float64
#  9   Fan slope(°)                             304 non-null    float64
# ...

# %%
data["Relief ratio"]=data1["Relief ratio"]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 55 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   ID                                             304 non-null    int64
#  1   Fan area (km^2)                                304 non-null    float64
#  2   Fan perimeter (km)                             304 non-null    float64
#  3   Fan length (km)                                304 non-null    float64
#  4   Fan width (km)                                 304 non-null    float64
#  5   Form factor of fan                             304 non-null    float64
#  6   Altura max (km)                                304 non-null    float64
#  7   Altura min (km)                                304 non-null    float64
#  8   Fan relief (km)                                304 non-null    float64
# ...

# %%
df=data.rename(columns={'Fan area (km^2)':"$A_f$", 'Fan perimeter (km)':"$P_f$", 'Fan length (km)':"$L_f$",
       'Fan width (km)':"$W_f$", 'Form factor of fan':"$Ff_f$", 'Altura max (km)':"$Hmax_f$",
   'Altura min (km)':"$Hmin_f$", 'Fan relief (km)':"$Rel_f$", 'Fan slope(°)':"$Sn_f$",
       'Pendiente media abanico (°)':"$Sd_f$", 'Fan profile curvature':"$V_{cur.}$",
       'Fan planform curvature':"$H_{cur.}$", 'Fan ruggednes ':"$Rug_f$", 'Fan volume (km^3)':"$Vol.$",
       'Tipo de Abanico':"Type", 'Tipo de asentamiento':"Settlement", 'Poblado':"People", 'Cordillera':"Cordillera",
       'Main stream order':"$\hat{S}o$", 'Number of streams ':"Sn", ' Stream length (km)':"Sl",
       'Main stream length (km)':"$Sl_{m}$", ' Stream length ratio':"Slr", "Bifurcation ratio":"Br",' Ro Coefficient':"Ro", 
        'Length of catchmen (km)':"$L_c$", 'Catchment area (km^2)':"$A_c$",
       'Catchment perimeter (km)':"$P_c$", 'Form factor':"$Ff_c$", ' Elongation ratio':"Er","Circularity ratio":"Cr",
       'Compactness coefficien':"Cc",'Constant of channel Maintenance':"Mc","Texture ratio":"Tr","Fitness ratio":"Fr","Wandering ratio":"Wt",
        "Stream frequency":"Sf","Drainage density":"Dd","Drainage intensity":"Di","Length of overland flow":"Lof","Catchment relief (km)":"$C_r$",
       'Infiltration numbe':"In", "Torrentiality coefficient":"Tc",' Slope  of  the  catchment  channel (°)':"$Sc_c$", 'Mean basin slope (°)':"$Sh_c$",
       'Theta angle':"$\theta$", 'Ruggedness number':"$R_c$", 'Melton index':"Im", 'Unidad geologica':"Geology",
       'Litologia':"Lithology", 'Subzona hidrografica':"Basin",
       'Type of Catchment, according to Arango (2021)':"Torrential",
       'Torrential flow reports':"Reports","Relief ratio":"Rr"})

# %%
df.head(2)
# Out:
#    ID     $A_f$    $P_f$    $L_f$    $W_f$    $Ff_f$  $Hmax_f$  $Hmin_f$  \
# 0   0  0.240791  2.53465  0.75725  0.62833  0.419915     0.699     0.667
# 1   1  0.159653  2.15590  0.78937  0.39793  0.256222     0.693     0.654
#
#    $Rel_f$    $Sn_f$  $Sd_f$  $V_{cur.}$  $H_{cur.}$  $Rug_f$    $Vol.$  \
# 0    0.032  4.225817  5.6904     -0.0215     -0.0171   0.7331  0.025375
# 1    0.039  4.940649  6.2614     -0.0066     -0.0185   0.7898  0.032237
#
#       Type               Settlement People  Cordillera  $\hat{S}o$   Sn  \
# 0  Aluvial  Casas rurales dispersas     Si  Occidental           4  449
# 1  Aluvial        Sin asentamientos     No  Occidental           4  129
#
#         Sl  $Sl_{m}$       Slr        Br        Ro  $L_c$   $A_c$   $P_c$  \
# 0  100.628     3.190  4.716946  4.011675  1.175805  3.359  12.503  15.399
# 1   24.441     1.805  1.481206  1.178194  1.257184  1.987   2.063   5.928
#
#      $Ff_c$        Er        Cr        Cc         Tr        Fr        Wt  \
# ...

# %%
df.to_excel("G:\My Drive\INVESTIGACION\PAPERS\ELABORACION\PAPER_FanCatchments/Data/Morphometry/fan.xlsx", index=False)
#sep='\t', encoding='utf-8', index=False, header=True, mode="w"

# %%
cat=gpd.read_file('G:/My Drive/INVESTIGACION/POSDOC/Data/Vector/torre_catchments.shp')
cat=cat.rename(columns={'id':'ID'})
cat=cat[["ID","geometry"]]
cat.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        304 non-null    int64
#  1   geometry  304 non-null    geometry
# dtypes: geometry(1), int64(1)
# memory usage: 4.9 KB

# %%
df_cat=df.merge(cat, on='ID')
gdf=GeoDataFrame(df_cat, crs="EPSG:32618", geometry='geometry')
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 56 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          304 non-null    int64
#  1   $A_f$       304 non-null    float64
#  2   $P_f$       304 non-null    float64
#  3   $L_f$       304 non-null    float64
#  4   $W_f$       304 non-null    float64
#  5   $Ff_f$      304 non-null    float64
#  6   $Hmax_f$    304 non-null    float64
#  7   $Hmin_f$    304 non-null    float64
#  8   $Rel_f$     304 non-null    float64
#  9   $Sn_f$      304 non-null    float64
#  10  $Sd_f$      304 non-null    float64
#  11  $V_{cur.}$  304 non-null    float64
#  12  $H_{cur.}$  304 non-null    float64
#  13  $Rug_f$     304 non-null    float64
#  14  $Vol.$      304 non-null    float64
#  15  Type        304 non-null    object
#  16  Settlement  304 non-null    object
#  17  People      304 non-null    object
# ...

# %%
gdf.head(2)
# Out:
#    ID     $A_f$    $P_f$    $L_f$    $W_f$    $Ff_f$  $Hmax_f$  $Hmin_f$  \
# 0   0  0.240791  2.53465  0.75725  0.62833  0.419915     0.699     0.667
# 1   1  0.159653  2.15590  0.78937  0.39793  0.256222     0.693     0.654
#
#    $Rel_f$    $Sn_f$  $Sd_f$  $V_{cur.}$  $H_{cur.}$  $Rug_f$    $Vol.$  \
# 0    0.032  4.225817  5.6904     -0.0215     -0.0171   0.7331  0.025375
# 1    0.039  4.940649  6.2614     -0.0066     -0.0185   0.7898  0.032237
#
#       Type               Settlement People  Cordillera  $\hat{S}o$   Sn  \
# 0  Aluvial  Casas rurales dispersas     Si  Occidental           4  449
# 1  Aluvial        Sin asentamientos     No  Occidental           4  129
#
#         Sl  $Sl_{m}$       Slr        Br        Ro  $L_c$   $A_c$   $P_c$  \
# 0  100.628     3.190  4.716946  4.011675  1.175805  3.359  12.503  15.399
# 1   24.441     1.805  1.481206  1.178194  1.257184  1.987   2.063   5.928
#
#      $Ff_c$        Er        Cr        Cc         Tr        Fr        Wt  \
# ...

# %%
gdf.to_file('G:\My Drive\INVESTIGACION\PAPERS\ELABORACION\PAPER_FanCatchments/Data/Spatial/Vector/gdf.shp', mode="w")
