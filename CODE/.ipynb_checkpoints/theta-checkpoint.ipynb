# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 36.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 48.9 MB/s eta 0:00:00
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=gpd.read_file('/content/drive/MyDrive/INVESTIGACION/POSDOC/Nechi/Vector/catchments_12m.shp')
data.head()
# Out:
#    fid   DN          layer                                               path  \
# 0  7.0  100    amaceri_12m  /media/edier/DATOS/INVESTIGACION/POSDOC/Nechi/...
# 1  4.0  100     amalfi_12m  /media/edier/DATOS/INVESTIGACION/POSDOC/Nechi/...
# 2  4.0  100   amalfiña_12m  /media/edier/DATOS/INVESTIGACION/POSDOC/Nechi/...
# 3  5.0  100     animas_12m  /media/edier/DATOS/INVESTIGACION/POSDOC/Nechi/...
# 4  2.0  100  animasita_12m  /media/edier/DATOS/INVESTIGACION/POSDOC/Nechi/...
#
#    hypso  mnoptim  mnoptivar  theta_dif  \
# 0  0.500    0.426      0.251        NaN
# 1  0.415    0.393      0.380        NaN
# 2  0.511    0.238      0.502        NaN
# 3  0.371    0.557      0.171        NaN
# 4  0.663    0.100      0.334        NaN
#
#                                             geometry
# 0  POLYGON ((548843.812 879913.125, 548868.812 87...
# 1  POLYGON ((508368.812 800200.625, 508443.812 80...
# 2  POLYGON ((497943.812 783663.125, 498018.812 78...
# ...

# %%
data.columns
# Out:
# Index(['fid', 'DN', 'layer', 'path', 'hypso', 'mnoptim', 'mnoptivar',
#        'theta_dif', 'geometry'],
#       dtype='object')

# %%
data["theta_dif"]=abs(data["mnoptim"]-data["mnoptivar"])
data.plot(column="theta_dif")
# Out:
# <Axes: >

# %%
data.to_file('/content/drive/MyDrive/INVESTIGACION/POSDOC/Nechi/Vector/catchments_12m.shp', driver="GeoJSON")
