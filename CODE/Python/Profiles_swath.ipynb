# %% [markdown]
# # PROFILES
#
# A continuacion se presentan uan serie de perfiles denominados swath profiles de oeste a este con un ancho de 5km, y de norte a sur con un ancho de 10km.

# %%
# !pip install geopandas

# %%
# !pip install contextily

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
#import geopandas as gpd
#import contextily as ctx
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # FIGURAS

# %%
aoi = gpd.read_file('/content/drive/MyDrive/INVESTIGACION/POSDOC/Data/Area_estudio/Area_estudio_poligono.shp')
for i in range(51):
  line = gpd.read_file(f"/content/drive/MyDrive/INVESTIGACION/POSDOC/Perfiles/NE/profile_NE{i}.geojson", driver='GeoJSON')
  f,ax = plt.subplots(1,figsize=(12, 12))
  aoi.plot(ax=ax,alpha=0.1, edgecolor="b")
  line.plot(ax=ax,edgecolor="red",lw=6)
  ctx.add_basemap(ax, crs=line.crs.to_string(), source=ctx.providers.OpenTopoMap)
  ax.set_axis_off()
  f.savefig(f"/content/drive/MyDrive/INVESTIGACION/POSDOC/Perfiles/NE/Localizacion_NE_P{i}.png", dpi=100)
  plt.clf()

  file  = np.genfromtxt(f"/content/drive/MyDrive/INVESTIGACION/POSDOC/Perfiles/NE/statslines_NE{i}.txt")
  fig, ax = plt.subplots(figsize=(20,10))
  ax.plot(file[:,0]/1000,file[:,1],'-',c='gray',lw=1)
  ax.plot(file[:,0]/1000,file[:,3],'-k',lw=1.5)
  plt.plot(file[:,0]/1000,file[:,2],'-',c='gray',lw=1)
  plt.ylabel('Elevation (m)',size=18)
  plt.xlabel('Distance along profile (km)',size=18)
  plt.yticks(size=14)
  plt.xticks(size=14)
  plt.axis([0,(max(file[:,0]/1000)),0,4500])
  x=file[:,0]/1000
  y1=file[:,1]
  y2=file[:,2]
  ax.fill_between(x,y1,y2, facecolor='r', alpha=0.4)
  #ax.fill_between(x,y1,y2, where=(x>24.2) ^ (x<33.2),facecolor='r', alpha=0.6)
  #ax.fill_between(x,y1,y2, where=(x>24.2)&(x<33.2),facecolor='g', alpha=0.6)
  plt.title(f"Profile {i}",size=22)
  #ax.plot([21.057, 42.998], [3250, 3250], 'k-', lw=2)
  #plt.text(25,3270,'Aburrá Valley', size=16)
  prof=mpimg.imread(f"/content/drive/MyDrive/INVESTIGACION/POSDOC/Perfiles/NE/Localizacion_NE_P{i}.png")
  imagebox=OffsetImage(prof,zoom=0.2)
  ab=AnnotationBbox(imagebox,(260,3400),frameon=False)
  ax.add_artist(ab)
  fig.savefig(f"/content/drive/MyDrive/INVESTIGACION/POSDOC/Perfiles/NE/P_NE{i}.png", dpi=100)
  plt.clf()
  os.remove(f"/content/drive/MyDrive/INVESTIGACION/POSDOC/Perfiles/NE/Localizacion_NE_P{i}.png")
