# %% [markdown]
# # connectivity

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
import geopandas as gpd
from pysal.lib import weights
from matplotlib_scalebar.scalebar import ScaleBar
import geodatasets
from geo_northarrow import add_north_arrow

# %%
gdf=gpd.read_file("G:/My Drive/INVESTIGACION/POSDOC/Data/Vector/catchments_OK.gpkg")

# %%
gdf.plot();

# %%
gdf.head(1)
# Out:
#                    Nombre  ID_CUENCA cuenca  \
# 0  Quebrada La Cristalina      501.0   Sinu
#
#                                             geometry
# 0  MULTIPOLYGON (((344147.840 850184.150, 344333....

# %%
w_queen = weights.contiguity.Rook.from_dataframe(gdf);
# Out:
# C:\Users\edier\AppData\Local\Temp\ipykernel_51668\1245547044.py:1: FutureWarning: `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
#   w_queen = weights.contiguity.Rook.from_dataframe(gdf);
# C:\Users\edier\miniconda3\Lib\site-packages\libpysal\weights\weights.py:224: UserWarning: The weights matrix is not fully connected:
#  There are 17 disconnected components.
#  There are 9 islands with ids: 165, 171, 191, 263, 377, 401, 413, 417, 506.
#   warnings.warn(message)

# %%
w_queen.nonzero
# Out:
# 2200

# %%
f, ax = plt.subplots(figsize=(9, 9))
gdf.plot(facecolor="none", edgecolor="gray",ax=ax)
w_queen.plot(gdf,edge_kws=dict(linewidth=0.7,color="red"),node_kws=dict(marker="."),ax=ax,)
add_north_arrow(ax, scale=.75, xlim_pos=.2, ylim_pos=.965, color='#000', text_scaler=4, text_yT=-1.25)
scalebar = ScaleBar(1,"m",location="lower right",scale_loc="top",length_fraction=0.25)
ax.add_artist(scalebar);
ax.set_axis_off()
ax.set_axis_off()
f.savefig('G:/My Drive/INVESTIGACION/POSDOC/Figuras/w_queen.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# ## catchments 2

# %%
gdf2=gpd.read_file("G:/My Drive/INVESTIGACION/POSDOC/Data/Vector/df_catchments_spatial.gpkg")

# %%
gdf2.plot();

# %%
gdf2.head(1)
# Out:
#    id          Nombre  ID_CUENCA cuenca       Área    elev_mean  elev_median  \
# 0   1  Quebrada Guaco      606.0  Cauca  18.430197  1615.334363       1607.0
#
#      rel_mean  rel_median  rainfallAnnual_mean  Densidad  hypso_inte  \
# 0  510.665139       505.0          2264.807895  18.23095       0.493
#
#    slope_mean kmeans  RainfallDaysmean  RainfallDaysmedian landcovermedian  \
# 0   29.278027      C       1112.245024              1066.0           grass
#
#   geomedian  lands_rec                                           geometry
# 0  sediment        4.0  POLYGON ((454732.740 622820.251, 454684.825 62...

# %%
w_queen2 = weights.contiguity.Rook.from_dataframe(gdf2);
# Out:
# C:\Users\edier\AppData\Local\Temp\ipykernel_51668\1723854934.py:1: FutureWarning: `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
#   w_queen2 = weights.contiguity.Rook.from_dataframe(gdf2);
# C:\Users\edier\miniconda3\Lib\site-packages\libpysal\weights\weights.py:224: UserWarning: The weights matrix is not fully connected:
#  There are 16 disconnected components.
#  There are 6 islands with ids: 140, 146, 198, 300, 332, 419.
#   warnings.warn(message)

# %%
w_queen2.nonzero
# Out:
# 1778

# %%
f, ax = plt.subplots(figsize=(9, 9))
gdf2.plot(facecolor="none", edgecolor="gray",ax=ax)
w_queen2.plot(gdf2,edge_kws=dict(linewidth=0.7,color="red"),node_kws=dict(marker="."),ax=ax,)
add_north_arrow(ax, scale=.75, xlim_pos=.2, ylim_pos=.965, color='#000', text_scaler=4, text_yT=-1.25)
scalebar = ScaleBar(1,"m",location="lower right",scale_loc="top",length_fraction=0.25)
ax.add_artist(scalebar);
ax.set_axis_off()
f.savefig('G:/My Drive/INVESTIGACION/POSDOC/Figuras2/w_queen.png', dpi=500, bbox_inches='tight')
