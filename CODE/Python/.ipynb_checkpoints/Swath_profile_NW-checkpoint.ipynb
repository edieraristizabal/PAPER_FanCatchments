# %%
# !pip install utm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for utm: filename=utm-0.7.0-py3-none-any.whl size=6108 sha256=5e7bc1d8270c79811d9059b43de97c0be51dc64293aee391d3492ac8e2f0ed25
#   Stored in directory: /root/.cache/pip/wheels/65/e2/d8/878a8cc986641056fbfebefc4d8eb64238a7b6d3426e86b447
# Successfully built utm
# ...

# %%
# !pip install rasterstats
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 20.9 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 16.6 MB 77.4 MB/s
# ...
#      |████████████████████████████████| 139 kB 77.3 MB/s
# ...

# %%
# !pip install progress
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for progress: filename=progress-1.6-py3-none-any.whl size=9630 sha256=f0e7c63e71bbbf54452f643030d2863bd0be2288ef0f6e8720d65cd32cf3419d
#   Stored in directory: /root/.cache/pip/wheels/bb/01/5a/c916509df9b12c6465864251dbe826def8e31a16fa7da54f08
# Successfully built progress
# ...

# %%
# !pip install pyswath
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 253 kB 4.7 MB/s
# ...
#   Created wheel for pyswath: filename=pyswath-2.0.4-py3-none-any.whl size=252838 sha256=96a900bf56bbc9bb16ad97079985bebb26e5997fbaa29d0c21aca5924283dcb1
#   Stored in directory: /root/.cache/pip/wheels/ef/59/a4/b83c56ae2162dee8a488ff8bbd3e31d74a7d30a2327a8b240a
# Successfully built pyswath
# ...

# %%
# !pip install geopandas

# %%
from pyswath import swathp
import numpy as np
import rasterio as rio
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
for i in range(42,51):
  swathp(rasterfnme = '/content/drive/MyDrive/INVESTIGACION/POSDOC/Data/CaucaMagdalena_DEM_30m.tif', A = [(300000.0,(5000.0*i+480000.0))], B = [(560000.0,(5000.0*i+670000.0))], Coord = 'synthetic', factor = 1000, xsteps = [30], boxwidths = [5000], binsize = 30, title = f"NW{i}", ylimmin = 0, ylimmax = 5000, shpbox = f"NW{i}.shp", corrnan = False, nodatav = -9999)
  file  = np.genfromtxt(f"/content/Data/statslines_NW{i}_0.txt")
  np.savetxt(f"/content/drive/MyDrive/INVESTIGACION/POSDOC/Perfiles/NW/statslines_NW{i}.txt",file)
  line = gpd.read_file(f"/content/SHP_NW{i}/line_NW{i}_1.shp")
  line.to_file(f"/content/drive/MyDrive/INVESTIGACION/POSDOC/Perfiles/NW/profile_NW{i}.geojson", driver='GeoJSON')
